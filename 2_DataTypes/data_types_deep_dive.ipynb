# %% [markdown]
# #### 1. Everything in Python is a class and object

# %%
import os
import sys

# %%
i = 10
i1 = 22
i2 = 10

# %%
print("Size allocated for an integer")
print(sys.getsizeof(i), sys.getsizeof(i1), sys.getsizeof(i2))

print("Memory address of the object")
print(id(i), id(i1), id(i2))
# Out:
# Size allocated for an integer
# 28 28 28
# Memory address of the object
# 140705048242904 140705048243288 140705048242904

# %%
print("Size allocated for an integer")
print(sys.getsizeof(10), sys.getsizeof(22))

print("Memory address of the object")
print(id(10), id(22))
# Out:
# Size allocated for an integer
# 28 28
# Memory address of the object
# 140705048242904 140705048243288

# %%
print(id(1))
print(type(1))
k=1
print(id(k))
print(type(k))

j=int(input("Please enter the number: "))
print(id(j))
print(type(j))
# Out:
# 140705048242616
# <class 'int'>
# 140705048242616
# <class 'int'>
# 140705048242648
# <class 'int'>

# %%
l=int(1.5)

# %%
print(id(l))
# Out:
# 140705048242616

# %%
fl = 3.14
fl2 = 3.143

print(id(fl), id(fl2))
# Out:
# 1961808098224 1961809621200
