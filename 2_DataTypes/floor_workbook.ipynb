# %%
#### Float

# Float is 64 bit (8 bytes) in size
# However, since it is a class, it shows 24 byte inlucdig python object overhead

# There is no default number of decimal positions
# 15-17 significant decimal digits

# %%
f1 = 10.2

# Type is
print(type(f1))
type(f1)
# Out:
# <class 'float'>
# float

# %%
f2=float() # Default constructor

f2 #Innitialized to 0.0
# Out:
# 0.0

# %%
id(f1),id(f2)
# Out:
# (2195954668272, 2195954675856)

# %%
print(f2,f1)
# Out:
# 0.0 10.2

# %%
i=10**1000

# %%
i
# Out:
# ...

# %%
import sys
sys.set_int_max_str_digits(100000)

# %%
fl1=30.14**13.99

# %%
fl1
# Out:
# 4.9341692137251655e+20

# %%
print(sys.getsizeof(1))
print(sys.getsizeof(10))
print(sys.getsizeof(10**10))
print(sys.getsizeof(10**100))
# Out:
# 28
# 28
# 32
# 72
