# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# #### Basic data types

# %%
import os
import sys
a = 10

print(a)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(sys.getsizeof(a))
# Out:
# 28

# %%
print(id(a))
# Out:
# 140705048242904

# %%
b=10

print(id(b))
print(id(10))
# Out:
# 140705048242904
# 140705048242904

# %%
b=b+1

print(id(b))
# Out:
# 140705048242936

# %%
del b

# %%
print(id(10))
# Out:
# 140705048242904

# %%
print(id("Hello"))
# Out:
# 1908269949952
