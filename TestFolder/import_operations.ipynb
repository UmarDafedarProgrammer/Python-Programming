# %%
import CustomPackage as CP

# %%
# CP.calculator.addition(5,6)

import sys
print(sys.executable)
# Out:
# C:\Users\umard\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe

# %%
CP.calculator.addition(5,6)
# Out:
# 11

# %%
from CustomPackage import SubPackage

# %%
SubPackage.calculatorSub.addition(3,5)
# Out:
# subpackage addition
# 8

# %%
from CustomPackage.calculator import *
from CustomPackage.SubPackage.calculatorSub import *

# %%
addition(4,5)
# Out:
# subpackage addition
# 9

# %%
from CustomPackage.calculator import addition,substraction

# %%
addition(4,5)
import CustomPackage.calculator

# %%
print(dir(CustomPackage.calculator))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'addition', 'division', 'multiplication', 'os', 'substraction', 'sys']

# %%
import CustomPackage.calculator

print(dir(CustomPackage))

print(CustomPackage.__doc__)
print(CustomPackage.__file__)
print(CustomPackage.__loader__)
# Out:
# ['SubPackage', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'calculator']
# None
# c:\users\umard\onedrive\desktop\generativeaistudy\repo\genai_venv\python-programming\CustomPackage\__init__.py
# ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
