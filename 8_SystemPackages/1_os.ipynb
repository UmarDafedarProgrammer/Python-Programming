# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
os.getcwd()
# Out:
# 'c:\\Users\\umard\\OneDrive\\Desktop\\GenerativeAIStudy\\Repo\\genai_venv\\Python-Programming\\8_SystemPackages'

# %%
os.chdir('..') # Change Directory

# %%
os.getcwd() # Get Current Working Directory
# Out:
# 'c:\\Users\\umard\\OneDrive\\Desktop\\GenerativeAIStudy\\Repo\\genai_venv\\Python-Programming'

# %%
# OLDPWD - Environment variable stores the previous working directory
# this is equivalent to cd -;
print(os.environ.get('PWD')) # This is being exuected in Python kernel. Thats why the environment variables are not shown
# Out:
# None

# %%
print(os.environ.get('OLDPWD'))
# Out:
# None

# %%
# os.environ
# list all the environment variables

# %%
os.listdir()
# Out:
# ['genai_venv']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\umard\\OneDrive\\Desktop\\GenerativeAIStudy\\Repo'

# %%
os.chdir("genai_venv\\Python-Programming")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\umard\\OneDrive\\Desktop\\GenerativeAIStudy\\Repo\\genai_venv\\Python-Programming'

# %%
# os.chdir("MissingDirectory")

# %%
os.mkdir("Test")

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.idea',
#  '1_Basics',
#  '2_DataTypes',
#  '3_Basics2',
#  '4_Functions',
#  '5_FileOperations',
#  '6_BuiltinFunctions',
#  '8_SystemPackages',
#  'autosys_jobs.jil',
#  'CustomPackage',
#  'DataFolder',
#  'misc',
#  'Packages',
#  'setup.py',
#  'string_package',
#  'Test',
#  'TestFolder',
#  'testing.py',
#  'UserPackages.egg-info',
#  'workload.py']

# %%
os.rmdir("Test")

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.idea',
#  '1_Basics',
#  '2_DataTypes',
#  '3_Basics2',
#  '4_Functions',
#  '5_FileOperations',
#  '6_BuiltinFunctions',
#  '8_SystemPackages',
#  'autosys_jobs.jil',
#  'CustomPackage',
#  'DataFolder',
#  'misc',
#  'Packages',
#  'setup.py',
#  'string_package',
#  'TestFolder',
#  'testing.py',
#  'UserPackages.egg-info',
#  'workload.py']

# %%
fd=os.open("filename.txt",os.O_CREAT)
os.close(fd)

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.idea',
#  '1_Basics',
#  '2_DataTypes',
#  '3_Basics2',
#  '4_Functions',
#  '5_FileOperations',
#  '6_BuiltinFunctions',
#  '8_SystemPackages',
#  'autosys_jobs.jil',
#  'CustomPackage',
#  'DataFolder',
#  'filename.txt',
#  'misc',
#  'Packages',
#  'setup.py',
#  'string_package',
#  'TestFolder',
#  'testing.py',
#  'UserPackages.egg-info',
#  'workload.py']

# %%
os.remove("filename.txt")

# %%
os.system("ls")
# Out:
# 1

# %%
print(os.system("ls -ltr"))
# Out:
# 1

# %%
print(os.system("ping google.com"))
# Out:
# 0
