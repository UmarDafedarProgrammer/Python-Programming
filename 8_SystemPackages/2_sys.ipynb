# %%
import sys

# %%
sys.argv[0]
# Out:
# 'C:\\Users\\umard\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\ipykernel_launcher.py'

# %%
sys.version
# Out:
# '3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]'

# %%
sys.platform
# Out:
# 'win32'

# %%
sys.path
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0',
#  '',
#  'C:\\Users\\umard\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages',
#  'c:\\users\\umard\\onedrive\\desktop\\generativeaistudy\\repo\\genai_venv\\python-programming',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib\\site-packages']

# %%
sys.stdout.write("Hello")
# Out:
# Hello
# 5

# %%
sys.stderr.write("Hello")
# Out:
# Hello
# 5

# %%
sys.getrecursionlimit()
# Out:
# 3000

# %%
sys.setrecursionlimit(200)

# %%
def fibonacci(a):
    if a == 0:
        return 1
    return a * fibonacci(a-1)

# %%
fibonacci(150)
# Out:
# 

# %%
sys.thread_info
# Out:
# sys.thread_info(name='nt', lock=None, version=None)

# %%
sys.implementation
# Out:
# namespace(name='cpython',
#           cache_tag='cpython-311',
#           version=sys.version_info(major=3, minor=11, micro=9, releaselevel='final', serial=0),
#           hexversion=51055088)

# %%
sys.displayhook
