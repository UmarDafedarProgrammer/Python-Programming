# %%
import math
import os
import sys

# %%
math.pi # PI Value
# Out:
# 3.141592653589793

# %%
math.tau # 2*Pi
# Out:
# 6.283185307179586

# %%
math.e # Eulers Number/ Exponent growth constant
# Out:
# 2.718281828459045

# %%
math.inf # Infinity
# Out:
# inf

# %%
math.nan # Not a Number
# Out:
# nan

# %%
math.sqrt(26) # square root of 26
# Out:
# 5.0990195135927845

# %%
math.pow(2,7) # 2 to the power 7 
# always returns floating point number
# Out:
# 128.0

# %%
2**7
# Out:
# 128

# %%
math.fabs(-23.67) # Floating point absolute value
# Out:
# 23.67

# %%
# Rounding
print(round(3.56))
print(round(3.4))
print(round(3.5))
# Out:
# 4
# 3
# 4

# %%
print(math.ceil(3.4)) # Towards positive infinity
print(math.ceil(-3.4))

# -4 -3 -2 -1 0 1 2 3 4
# Out:
# 4
# -3

# %%
print(math.floor(3.4)) # Towards Negative infinity
print(math.floor(-3.4))
# Out:
# 3
# -4

# %%
print(math.trunc(3.4)) # Just  truncate the decimal position, No Rounding
print(math.trunc(-3.4))
# Out:
# 3
# -3

# %%
print(math.log(10))        # natural log (base e)
print(math.log10(100))     # base 10
print(math.log2(8))        # base 2
# Out:
# 2.302585092994046
# 2.0
# 3.0

# %%
math.pow(math.e,math.log(10))
# Out:
# 10.000000000000002

# %%
# Exponential function
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.pow(math.e,2)
# Out:
# 7.3890560989306495

# %%
# Trignometry
print(math.sin(90))
print(math.cos(90))
print(math.tan(90))

# strange isnot it
print()

radian_90degree = 90*math.pi/180
print(round(math.sin(radian_90degree)))
print(round(math.cos(radian_90degree)))
print(round(math.tan(radian_90degree)))
# Out:
# 0.8939966636005579
# -0.4480736161291701
# -1.995200412208242
#
# 1
# 0
# 16331239353195370

# %%
tan90Degree = math.tan(radian_90degree) # its finite large number

math.isinf(tan90Degree)
# Out:
# False

# %%
# Distance and Geometry

print(math.hypot(3,4))
# Out:
# 5.0

# %%
math.dist([0,0],[3,4])
# Out:
# 5.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.comb(5,3)
# Out:
# 10

# %%
math.perm(10,20)
# Out:
# 0

# %%
math.perm(5,3)
# Out:
# 60

# %%
math.gcd(5,2)
# Out:
# 1

# %%
math.gcd(100,50)
# Out:
# 50

# %%
math.lcm(4,20)
# Out:
# 20

# %%
math.isfinite(math.inf)
# Out:
# False

# %%
math.isfinite(10)
# Out:
# True
