# %%
path = "C:/Users/umard/OneDrive/Desktop/Repo/GenerativeAI/virt_env_dev/Repo/Python-Programming/DataFolder"
fileName = "Sample.txt"

print(path)
print(fileName)
# Out:
# C:/Users/umard/OneDrive/Desktop/Repo/GenerativeAI/virt_env_dev/Repo/Python-Programming/DataFolder
# Sample.txt

# %%
# fileobject.read() -> reads the entire content
file_path=f"{path}/{fileName}"
with open(file_path,'r') as file_read: 
    content=file_read.read() #read the entire content
    print(content)
# Out:
# ------------------------------------------------------------
#                   MONTHLY SALES REPORT - AUGUST 2025
# ------------------------------------------------------------
#
# Company: Acme Retail Inc.
# Report Generated: September 1, 2025
#
# Prepared By: Data Analytics Department
#
# ------------------------------------------------------------
# | Item ID | Item Name        | Quantity Sold | Unit Price | Total      |
# ------------------------------------------------------------
# | 101     | Wireless Mouse   | 120           | $25.00     | $3,000.00  |
# | 102     | USB Keyboard     | 85            | $20.00     | $1,700.00  |
# | 103     | Laptop Stand     | 60            | $35.00     | $2,100.00  |
# | 104     | HDMI Cable       | 200           | $10.00     | $2,000.00  |
# | 105     | Portable Charger | 45            | $40.00     | $1,800.00  |
# ------------------------------------------------------------
#
# Total Items Sold: 510
# Total Revenue: $10,600.00
#
# Notes:
# ...

# %%
with open(file_path,'r') as file_object:
    for line in file_object:
        print(line.strip())
# Out:
# ------------------------------------------------------------
# MONTHLY SALES REPORT - AUGUST 2025
# ------------------------------------------------------------
#
# Company: Acme Retail Inc.
# Report Generated: September 1, 2025
#
# Prepared By: Data Analytics Department
#
# ------------------------------------------------------------
# | Item ID | Item Name        | Quantity Sold | Unit Price | Total      |
# ------------------------------------------------------------
# | 101     | Wireless Mouse   | 120           | $25.00     | $3,000.00  |
# | 102     | USB Keyboard     | 85            | $20.00     | $1,700.00  |
# | 103     | Laptop Stand     | 60            | $35.00     | $2,100.00  |
# | 104     | HDMI Cable       | 200           | $10.00     | $2,000.00  |
# | 105     | Portable Charger | 45            | $40.00     | $1,800.00  |
# ------------------------------------------------------------
#
# Total Items Sold: 510
# Total Revenue: $10,600.00
#
# Notes:
# ...

# %%
#### readlines() reads the content of file with \n newline for each line
with open(file_path,'r') as file_object:
    content=file_object.readlines()
    print(content)
# Out:
# ['------------------------------------------------------------\n', '                  MONTHLY SALES REPORT - AUGUST 2025\n', '------------------------------------------------------------\n', '\n', 'Company: Acme Retail Inc.\n', 'Report Generated: September 1, 2025\n', '\n', 'Prepared By: Data Analytics Department\n', '\n', '------------------------------------------------------------\n', '| Item ID | Item Name        | Quantity Sold | Unit Price | Total      |\n', '------------------------------------------------------------\n', '| 101     | Wireless Mouse   | 120           | $25.00     | $3,000.00  |\n', '| 102     | USB Keyboard     | 85            | $20.00     | $1,700.00  |\n', '| 103     | Laptop Stand     | 60            | $35.00     | $2,100.00  |\n', '| 104     | HDMI Cable       | 200           | $10.00     | $2,000.00  |\n', '| 105     | Portable Charger | 45            | $40.00     | $1,800.00  |\n', '------------------------------------------------------------\n', '\n', '
# ...

# %%
content
# Out:
# ['------------------------------------------------------------\n',
#  '                  MONTHLY SALES REPORT - AUGUST 2025\n',
#  '------------------------------------------------------------\n',
#  '\n',
#  'Company: Acme Retail Inc.\n',
#  'Report Generated: September 1, 2025\n',
#  '\n',
#  'Prepared By: Data Analytics Department\n',
#  '\n',
#  '------------------------------------------------------------\n',
#  '| Item ID | Item Name        | Quantity Sold | Unit Price | Total      |\n',
#  '------------------------------------------------------------\n',
#  '| 101     | Wireless Mouse   | 120           | $25.00     | $3,000.00  |\n',
#  '| 102     | USB Keyboard     | 85            | $20.00     | $1,700.00  |\n',
#  '| 103     | Laptop Stand     | 60            | $35.00     | $2,100.00  |\n',
#  '| 104     | HDMI Cable       | 200           | $10.00     | $2,000.00  |\n',
#  '| 105     | Portable Charger | 45            | $40.00     | $1,800.00  |\n',
# ...

# %%
file_to_write=f'{path}/writer.txt'

# %%
file_content = ['Hello Everyone\n','How are you?\n','Welcome to the file\n']

# %%
with open(file_to_write,'w') as file_write_object:
    file_write_object.write("Hello, How are you ?\n")
    file_write_object.write("whats up with file operations\n")
    file_write_object.write("Lets try to add few more lines\n")

# %%
with open(file_to_write,'w+') as file_write_object:
    file_write_object.write("Hello, How are you ?\n")
    file_write_object.write("whats up with file operations\n")
    file_write_object.write("Lets try to add few more lines\n")

    content=file_write_object.read()
    print(content)

# %%
with open(file_to_write,'w+') as file_write_object:
    file_write_object.write("Hello, How are you ?\n")
    file_write_object.write("whats up with file operations\n")
    file_write_object.write("Lets try to add few more lines\n")

    file_write_object.seek(0)
    content=file_write_object.read()
    print(content)
# Out:
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines

# %%
content=''

with open(file_to_write,'w+') as file_write_object:
    file_write_object.write("Hello, How are you ?\n")
    file_write_object.write("whats up with file operations\n")
    file_write_object.write("Lets try to add few more lines\n")

    file_write_object.seek(0)
    content=file_write_object.read()
    print(content)
# Out:
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines

# %%
print(content)
# Out:
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines

# %%
with open(file_to_write,'a') as file_write_object:
    file_write_object.write("Append Hello, How are you ?\n")
    file_write_object.write("Append whats up with file operations\n")
    file_write_object.write("Append Lets try to add few more lines\n")

# %%
with open(file_to_write,'r') as file_read_object:
    for line in file_read_object:
        print(line.strip())
    
    content=file_read_object.read()
    print("-------------------------------")
    print(content) # as the cursor is pointing to the end of the line as it is read till the end

    file_read_object.seek(0) # Set the cursor to point to the zero line
    content=file_read_object.read()
    print("-------------------------------")
    print(content)

    file_read_object.seek(5) # Point the cursor point to the 5th line
    content=file_read_object.read()
    print("-------------------------------")
    print(content) 

    # file_read_object.seek(-5,2) # Point the cursor point to the 5th line
    # content=file_read_object.read()
    # print("-------------------------------")
    # print(content)
# Out:
# abc
# 123
# 456
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines
# Append Hello, How are you ?
# Append whats up with file operations
# Append Lets try to add few more lines
# -------------------------------
#
# -------------------------------
# abc
# 123
# 456
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines
# Append Hello, How are you ?
# Append whats up with file operations
# Append Lets try to add few more lines
#
# -------------------------------
# 123
# 456
# Hello, How are you ?
# whats up with file operations
# Lets try to add few more lines
# Append Hello, How are you ?
# Append whats up with file operations
# Append Lets try to add few more lines
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[38], line 19
#      16 print("-------------------------------")
#      17 print(content)
# ...
